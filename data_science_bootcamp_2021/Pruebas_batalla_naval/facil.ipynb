# %%
#TABLERO

board = []
for x in range(10):
    board.append(["~"] * 10)

def print_board(board):
    for row in board:
        print (" ".join(row))

def ubicar_barco(board):
    for row in board:
        print (" ".join(row))


def ubicar_barco(fila, colum):
    print_board[fila][colum] = "#"
    colum = colum + 1

def seguimiento(board):
    for row in board:
        print(" ".join(row))

# %%
#FUNCION DE TURNOS
def player_turns(turn1, turn2): 
    """function to define the player 
    who starts the game"""
    number1 = random.randint(1, 6)
    print(f'Number of {turn1} is {number1}')
    number2 = random.randint(1, 6)
    print(f'Number of {turn2} is {number2}')
    if number1 > number2:
        player1 = turn1
        player2 = turn2
        print(f'{turn1} start the game and is the player1')
        return player1, player2
    else:
        player1 = turn2 
        player2 = turn1 
        print(f'{turn2} start the game and is the player1')
        return player1, player2

player_turns("Karina", "Marycruz")

# %%
#starting the game and printing the board
print("Empecemos el Juego") 
print(turno "Tu empiezas, ubica tus barcos")
print_board(board)

#defining where the ship is

def get_coor(board):
    numero_barcos = 10 
    ships = {"ship 2x1":4,
		     "ship 3x1":3,
 		     "ship 4x1 ":2,
		     "ship 5x1":1}
    for barco, cantidad in ships.items():

            
            while numero_barcos >0:
                print_board(board)
                try:
                    print("Estado inicial de la flota, inserte el %s" % (barco))
    

                    user_input = input("Inserte las coordenadas del 1 al 10 en formato nhn:n(filas/horizontal/columnas) o nvn:n (columna/vertical/filas)")
                    if user_input in "v":
                        for elem in user_input:
                            if 'v' in elem:
                                                    
                                fila = []
                                colum = []
                                
                                colum.append(int(elem[0]))
                                fila.append(int(elem[2:4]))
                                seguimientov = ubicar_barco(fila, colum)
                                numero_barcos -= 1
                            else:
                                if 'h' in elem:
                                    fila = []
                                    colum = []
                                    fila.append(int(elem[0]))
                                    colum.append(int(elem[2:4]))
                                    seguimientoh = ubicar_barco(fila, colum)
                                    numero_barcos -= 1
                except ValueError:
                    print("Don't you remember your training?\nType a number..\n")
# Out:
#   File "<ipython-input-17-ea4e3db354e1>", line 3
#     print(turno "Tu empiezas, ubica tus barcos")
#                                               ^
# SyntaxError: invalid syntax

# %%
get_coor(board)
# Out:
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-df21f6485af4> in <module>
# ----> 1 get_coor(board)
#
# <ipython-input-13-5013b4fc7ca3> in get_coor(board)
#      34                 print_board(board)
#      35                 try:
# ---> 36                     print("Estado inicial de la flota, inserte el %s" % (ship))
#      37
#      38
#
# NameError: name 'ship' is not defined

# %%
def search_locations(size, orientation):
  locations = []

  if orientation != 'horizontal' and orientation != 'vertical':
    raise ValueError("Orientation must have a value of either 'horizontal' or 'vertical'.")

  if orientation == 'horizontal':
    if size <= col_size:
      for r in range(row_size):
        for c in range(col_size - size + 1):
          if 1 not in board[r][c:c+size]:
            locations.append({'row': r, 'col': c})
  elif orientation == 'vertical':
    if size <= row_size:
      for c in range(col_size):
        for r in range(row_size - size + 1):
          if 1 not in [board[i][c] for i in range(r, r+size)]:
            locations.append({'row': r, 'col': c})

# %%
   def place_ship(board, ship, orientacion, fila, columna):
        
        # orientacion de los barcos
        if orientacion == "v":
            for i in range(ship):
                board[fila + i][columna]
        elif orientacion == "h":
            for i in range(ship):
                board[fila][columna + i]

        return board

# %%
#asignar mediante numpy a un tablero

import numpy as np
tablero = np.full((10,10), " ")

barco_1 = tablero[0:2, 1:2] = "O"
barco_2 = tablero[1:2:,3:7] = "O"
tablero

# %%
contador = 0
while contador < 2:
    fil = input("Introduce fila")
    col = input("Introduce columna")
    matriz[int(fil),int(col)] = "#"
    contador += 1

matriz

#Ship Class
tamaño_colum = 9 #number of columns
tamaño_fila = 9
num_barcos = 10
tamaño_max_barco = 5
tamaño_min_barco = 2
num_turns = 40

ships = {"ship 2x1":4,
		     "ship 3x1":3,
 		     "ship 4x1 ":2,
		     "ship 5x1":1}

def get_coor(board):
     
    
    for barco, cantidad in ships.items():

        while num_barcos >0:

            print("Cree el estado inicial de la flota, inserte el %s" % (barco))
            user_input = input("Inserte coordenadas en el siguiente formato: nhn:n(filas|horizontal|columnas(1:10)) o nvn:n columnas|horizontal|filas(1:10)")
            if 'v' in user_input:
                for elem in user_input:
                    
                    fila = []
                    colum = []
                    tamaño = int(elem[4] - elem[2] + 1)
                    colum.append(int(elem[0]))
                    fila.append(int(elem[2:4]))
                    #ubicar_barco[fila,colum]
                    num_barcos -=1
            else: 
                if 'h' in elem:
                    fila = []
                    colum = []
                    tamaño = int(elem[4] - elem[2] + 1)
                    fila.append(int(elem[0]))
                    colum.append[(int(elem[2:4]))
                    #ubicar_barco[fila, colum]
                    
                    num_barcos -=1
            print('Barcos ok')
# Out:
#   File "<ipython-input-21-25b488e9bee1>", line 51
#     num_barcos -=1
#              ^
# SyntaxError: invalid syntax

# %%
user_input = input("Inserte coordenadas en el siguiente formato: nhn:n(filas|horizontal|columnas(1:10)) o nvn:n columnas|horizontal|filas(1:10)")
    if 'v' in user_input:
                for elem in user_input:
                    fila = []
                    colum = []
                    colum.append(int(elem[0]))
                    fila.append(int(elem[2:4]))
                    #ubicar_barco[fila,colum]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-df21f6485af4> in <module>
# ----> 1 get_coor(board)
#
# NameError: name 'get_coor' is not defined

# %%
 
		if player1_input == "v" or player1_input == "h":
			return player1_input
		else:
			ValueError("Orientation must have a value of either 'horizontal' or 'vertical'.")

            
           try:
                    
    

                    user_input = input("Inserte las coordenadas del 1 al 10 en formato nhn:n(filas/horizontal/columnas) o nvn:n (columna/vertical/filas)")
                    if user_input in "v":
                        for elem in user_input:
                            if 'v' in elem:
                                                    
                                fila = []
                                colum = []
                                        
            
	#get ship orientation from player 1
	
		
def get_coor():
	
	while (True):
		player1_input = raw_input("Enter the positions (row,col) ? ")
		try:
			#Entered 2 values seprated by comma
			coor = player1_input.split(",")
			if len(coor) != 2:
				raise Exception("Sintax invalid, too few/many values");

			#check that 2 values are integers
			coor[0] = int(coor[0])-1
			coor[1] = int(coor[1])-1

			if coor[0] > 9 or coor[0] < 0 or coor[1] > 9 or coor[1] < 0:
				raise Exception("Only values between 1 to 10 only are allowed")

			return coor
		
		except ValueError:
			print "Invalid entry. Please enter only numeric values for coordinates"

# %%
def ubicar_barco(board):

    contador = 0
    while contador < 2:
        fil = input("Introduce fila")
        col = input("Introduce columna")
        board[int(fil),int(col)] = "#"
        contador += 1
ubicar_barco(board=board)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-0fb2bc3a1e51> in <module>
#       7         board[int(fil),int(col)] = "#"
#       8         contador += 1
# ----> 9 ubicar_barco(board=board)
#
# <ipython-input-11-0fb2bc3a1e51> in ubicar_barco(board)
#       5         fil = input("Introduce fila")
#       6         col = input("Introduce columna")
# ----> 7         board[int(fil),int(col)] = "#"
#       8         contador += 1
#       9 ubicar_barco(board=board)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
#MATIAS 

def ubicar_barco(board):

    print("Ubica el barco %s" % (ship))
    fila_inicio = int(input("Selecciona Fila -----> "))
    col_inicio = int(input("Selecciona Columna -----> "))
    tamano = int(input("Selecciona Tamano del barco -----> "))
    orientacion = str(input("Vertical o Horizontal? (v o h) -----> "))

    if orientacion == 'h':
        
            fila_fin = fila_inicio
            colum_fin = col_inicio + tamano
    
    else:
        orientacion == 'v':
            fila_fin = fila_inicio + tamano
            colum_fin = col_inicio

ubicar_barco(board=board)
# Out:
#   File "<ipython-input-16-0fce4cc1e7c3>", line 17
#     orientacion == 'v':
#                        ^
# SyntaxError: invalid syntax

# %%
#Create lists
ship_list = []
ships = {"ship 2x1":4,
		     "ship 3x1":3,
 		     "ship 4x1 ":2,
		     "ship 5x1":1}


def ubicar_barcos():
  
    for barco, cantidad in ships.items():
        
        while num_barcos >0:

            print("Cree el estado inicial de la flota, inserte el %s" % (barco))
            user_input = input("Inserte coordenadas en el siguiente formato: nhn:n(filas|horizontal|columnas(1:10)) o nvn:n columnas|horizontal|filas(1:10)")

    
    if orientation == 'horizontal' or orientation == 'vertical':
      self.orientation = orientation
    else:
      raise ValueError("Value must be 'horizontal' or 'vertical'.")
    
    if orientation == 'horizontal':
      if location['row'] in range(row_size):
        self.coordinates = []
        for index in range(size):
          if location['col'] + index in range(col_size):
            self.coordinates.append({'row': location['row'], 'col': location['col'] + index})
          else:
            raise IndexError("Column is out of range.")
      else:
        raise IndexError("Row is out of range.")
    elif orientation == 'vertical':
      if location['col'] in range(col_size):
        self.coordinates = []
        for index in range(size):
          if location['row'] + index in range(row_size):
            self.coordinates.append({'row': location['row'] + index, 'col': location['col']})
          else:
            raise IndexError("Row is out of range.")
      else:
        raise IndexError("Column is out of range.")

    if self.filled():
      print_board(board)
      print(" ".join(str(coords) for coords in self.coordinates))
      raise IndexError("A ship already occupies that space.")
    else:
      self.fillBoard()
  
  def filled(self):
    for coords in self.coordinates:
      if board[coords['row']][coords['col']] == 1:
        return True
    return False
  
  def fillBoard(self):
    for coords in self.coordinates:
      board[coords['row']][coords['col']] = 1

  def contains(self, location):
    for coords in self.coordinates:
      if coords == location:
        return True
    return False
def search_locations(size, orientation):
  locations = []

  if orientation != 'horizontal' and orientation != 'vertical':
    raise ValueError("Orientation must have a value of either 'horizontal' or 'vertical'.")

  if orientation == 'horizontal':
    if size <= col_size:
      for r in range(row_size):
        for c in range(col_size - size + 1):
          if 1 not in board[r][c:c+size]:
            locations.append({'row': r, 'col': c})
  elif orientation == 'vertical':
    if size <= row_size:
      for c in range(col_size):
        for r in range(row_size - size + 1):
          if 1 not in [board[i][c] for i in range(r, r+size)]:
            locations.append({'row': r, 'col': c})

  if not locations:
    return 'None'
  else:
    return locations

temp = 0
while temp < num_ships:
  ship_info = random_location()
  if ship_info == 'None':
    continue
  else:
    ship_list.append(Ship(ship_info['size'], ship_info['orientation'], ship_info['location']))
    temp += 1
del temp

# %%
#Create lists
ship_list = []

class Ship:
  def __init__(self, size, orientation, location):
    self.size = size
    
    if orientation == 'horizontal' or orientation == 'vertical':
      self.orientation = orientation
    else:
      raise ValueError("Value must be 'horizontal' or 'vertical'.")
    
    if orientation == 'horizontal':
      if location['row'] in range(row_size):
        self.coordinates = []
        for index in range(size):
          if location['col'] + index in range(col_size):
            self.coordinates.append({'row': location['row'], 'col': location['col'] + index})
          else:
            raise IndexError("Column is out of range.")
      else:
        raise IndexError("Row is out of range.")
    elif orientation == 'vertical':
      if location['col'] in range(col_size):
        self.coordinates = []
        for index in range(size):
          if location['row'] + index in range(row_size):
            self.coordinates.append({'row': location['row'] + index, 'col': location['col']})
          else:
            raise IndexError("Row is out of range.")
      else:
        raise IndexError("Column is out of range.")

    if self.filled():
      print_board(board)
      print(" ".join(str(coords) for coords in self.coordinates))
      raise IndexError("A ship already occupies that space.")
    else:
      self.fillBoard()
  
  def filled(self):
    for coords in self.coordinates:
      if board[coords['row']][coords['col']] == 1:
        return True
    return False
  
  def fillBoard(self):
    for coords in self.coordinates:
      board[coords['row']][coords['col']] = 1

  def contains(self, location):
    for coords in self.coordinates:
      if coords == location:
        return True
    return False
def search_locations(size, orientation):
  locations = []

  if orientation != 'horizontal' and orientation != 'vertical':
    raise ValueError("Orientation must have a value of either 'horizontal' or 'vertical'.")

  if orientation == 'horizontal':
    if size <= col_size:
      for r in range(row_size):
        for c in range(col_size - size + 1):
          if 1 not in board[r][c:c+size]:
            locations.append({'row': r, 'col': c})
  elif orientation == 'vertical':
    if size <= row_size:
      for c in range(col_size):
        for r in range(row_size - size + 1):
          if 1 not in [board[i][c] for i in range(r, r+size)]:
            locations.append({'row': r, 'col': c})

  if not locations:
    return 'None'
  else:
    return locations

temp = 0
while temp < num_ships:
  ship_info = random_location()
  if ship_info == 'None':
    continue
  else:
    ship_list.append(Ship(ship_info['size'], ship_info['orientation'], ship_info['location']))
    temp += 1
del temp

# %%
# Create the ships

temp = 0
while temp < num_ships:
  ship_info = random_location()
  if ship_info == 'None':
    continue
  else:
    ship_list.append(Ship(ship_info['size'], ship_info['orientation'], ship_info['location']))
    temp += 1
del temp
