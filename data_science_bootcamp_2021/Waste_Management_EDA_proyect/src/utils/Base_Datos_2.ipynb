# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %%
### Step 2. Import the datasets

##### * I have several databases in excel format
##### * xlrd is installed to read xls file
##### * openpyxl is installed to read xlsx file

# %%
df_2 = pd.read_excel("data/Evolución de materiales recuperados, compost y rechazos.xls")

# %%
df_1 = pd.read_excel("data/Coste del tratamiento de los residuos urbanos.xls")
df_2 = pd.read_excel("data/Evolución de materiales recuperados, compost y rechazos.xls")

df_4 = pd.read_excel("data/Ingresos registrados.xlsx")

df_6 = pd.read_excel("data/Recogida de vidrio, papel y pilas por mes.xls")

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Medio Ambiente  26 non-null     object
#  1   Unnamed: 1      23 non-null     object
#  2   Unnamed: 2      23 non-null     object
#  3   Unnamed: 3      23 non-null     object
#  4   Unnamed: 4      23 non-null     object
#  5   Unnamed: 5      23 non-null     object
#  6   Unnamed: 6      23 non-null     object
#  7   Unnamed: 7      23 non-null     float64
#  8   Unnamed: 8      23 non-null     float64
#  9   Unnamed: 9      23 non-null     float64
#  10  Unnamed: 10     23 non-null     float64
#  11  Unnamed: 11     23 non-null     float64
#  12  Unnamed: 12     23 non-null     float64
#  13  Unnamed: 13     23 non-null     float64
#  14  Unnamed: 14     23 non-null     float64
#  15  Unnamed: 15     23 non-null     float64
#  16  Unnamed: 16     23 non-null     float64
# ...

# %%
### Step 3. Have a look at the dataset.

# %% [markdown]
# ## DATAFRAME 2

# %%
# -Eliminar las filas de arriba y abajo que no sirven

df_2 = df_2.loc[5:26, :]
df_2
# Out:
#                                        Medio Ambiente Unnamed: 1 Unnamed: 2  \
# 5                        Total materiales recuperados    162.449    182.188
# 6                        Recuperados en planta. Total     76.213     87.809
# 7                Recogida selectiva aportación. Total     86.236     94.379
# 8                                 Papel cartón. Total     98.551    113.328
# 9                  Papel cartón. Recuperado en planta     38.803     47.102
# 10        Papel cartón. Recogida selectiva aportación     59.748     66.226
# 11                                      Vidrio. Total     27.576     29.169
# 12                       Vidrio. Recuperado en planta      1.088      1.016
# 13              Vidrio. Recogida selectiva aportación     26.488     28.153
# 14               Otros materiales recogidos en planta     36.322     39.691
# 15    Otros materiales recogidos en planta. Plásticos      6.784      7.556
# ...

# %%
# Eliminamos las columnas que no vamos a utilizar
df_2 = df_2.drop(columns=['Unnamed: 1','Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5', 'Unnamed: 6'], axis=1)

# %%
# -Cambiar de nombre a las columnas
df_2.columns = ['Materiales recuperados','2010','2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
df_2.head()
# Out:
#                  Materiales recuperados     2010     2011     2012     2013  \
# 5          Total materiales recuperados  214.150  184.781  169.171  154.473
# 6          Recuperados en planta. Total   89.955   81.733   76.317   72.674
# 7  Recogida selectiva aportación. Total  124.195  103.048   92.854   81.799
# 8                   Papel cartón. Total  117.858   93.144   80.230   66.254
# 9    Papel cartón. Recuperado en planta   36.773   32.462   29.780   26.298
#
#       2014     2015     2016     2017     2018     2019
# 5  147.800  139.991  146.269  159.969  191.323  206.319
# 6   71.083   67.840   67.513   68.168   77.270   73.616
# 7   76.717   72.151   78.756   91.802  114.052  132.702
# 8   60.929   50.895   55.129   63.868   19.268   89.690
# 9   24.560   22.568   22.008   20.803   19.268   16.215

# %%
# GUARDAR LA BASE DE DATOS LIMPIA
df_2_copy.to_csv('bd2_cleaned_evol_mater_recuper.csv', index=False)

# %%
# Reiniciar el index

df_2_copy = df_2.reset_index(drop = True)

# %%
df_2_copy
# Out:
#                                Materiales recuperados     2010     2011  \
# 0                        Total materiales recuperados  214.150  184.781
# 1                        Recuperados en planta. Total   89.955   81.733
# 2                Recogida selectiva aportación. Total  124.195  103.048
# 3                                 Papel cartón. Total  117.858   93.144
# 4                  Papel cartón. Recuperado en planta   36.773   32.462
# 5         Papel cartón. Recogida selectiva aportación   81.085   60.682
# 6                                       Vidrio. Total   44.071   43.532
# 7                        Vidrio. Recuperado en planta  961.000    1.166
# 8               Vidrio. Recogida selectiva aportación   43.110   42.366
# 9                Otros materiales recogidos en planta   52.221   48.105
# 10    Otros materiales recogidos en planta. Plásticos   21.215   19.774
# 11  Otros materiales recogidos en planta. Ferromag...   16.827   17.159
# ...

# %%
#Trasponer las filas a columnas --AUN NO LO HE HECHO 

df_2_copy =df_2_copy.T

# %%
df_2_copy
# Out:
# Materiales recuperados Total materiales recuperados  \
# 2010                                         214.15
# 2011                                        184.781
# 2012                                        169.171
# 2013                                        154.473
# 2014                                          147.8
# 2015                                        139.991
# 2016                                        146.269
# 2017                                        159.969
# 2018                                        191.323
# 2019                                        206.319
#
# Materiales recuperados Recuperados en planta. Total  \
# 2010                                         89.955
# 2011                                         81.733
# 2012                                         76.317
# 2013                                         72.674
# 2014                                         71.083
# 2015                                          67.84
# ...

# %%
# Le cambio el nombre a las columnas
df_2_copy.columns = df_2_copy.iloc[0]

# %%
#Elimino la primera fila que quedo repetida

df_2_copy = df_2_copy.iloc[1: , :]

# %%
df_2_copy
# Out:
# Materiales recuperados Total materiales recuperados  \
# 2010                                         214.15
# 2011                                        184.781
# 2012                                        169.171
# 2013                                        154.473
# 2014                                          147.8
# 2015                                        139.991
# 2016                                        146.269
# 2017                                        159.969
# 2018                                        191.323
# 2019                                        206.319
#
# Materiales recuperados Recuperados en planta. Total  \
# 2010                                         89.955
# 2011                                         81.733
# 2012                                         76.317
# 2013                                         72.674
# 2014                                         71.083
# 2015                                          67.84
# ...

# %%
df_2_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 2010 to 2019
# Data columns (total 22 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Total materiales recuperados                                      10 non-null     object
#  1   Recuperados en planta. Total                                      10 non-null     object
#  2   Recogida selectiva aportación. Total                              10 non-null     object
#  3   Papel cartón. Total                                               10 non-null     object
#  4   Papel cartón. Recuperado en planta                                10 non-null     object
#  5   Papel cartón. Recogida selectiva aportación                       10 non-null     object
#  6   Vidrio. Total                                                     10 non-null     object
# ...
